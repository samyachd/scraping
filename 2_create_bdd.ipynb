# %% [markdown]
# # Traitement et stockage des données issues du scraping
#
# Vous avez scrapé les données du site de livres et les avez stockées dans un fichier (CSV ou JSON).
#
# L'objectif de ce notebook est de créer une base de données pour y stocker ces données.

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# Chercher dans la doc [pandas](https://pandas.pydata.org/docs/) la fonction permettant de lire les données d'un fichier (CSV ou JSON).

# %%
# Lire les données du fichier que vous venez d'enregistrer
df_books =

# %% [markdown]
# ## 1. Prétraitement des données
#
# On souhaite créer la table _book_ contenant les attributs suivants :
# - id : INT, PK,
# - title : TEXT,
# - price : DECIMAL
# - availability : BOOLEAN
# - rating : INT [0:5]
#
# Vérifier que les données du dataframe ont les types attendus en utilisant la méthode pandas [_info_](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html).

# %%
# Vérification des types de données
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1000 non-null   object
#  1   price         1000 non-null   object
#  2   rating        1000 non-null   object
#  3   availability  1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %% [markdown]
# Utiliser la méthode pandas [_astype_](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html) pour convertir la colonne de titre en chaîne de caractère.

# %%
# Conversion de title en chaîne de caractères
df_books["title"] = 

# Vérification du type de la colonne title
print(df_books["title"].dtype)
# Out:
# object

# %% [markdown]
# Pour convertir la colonne de prix en nombre décimal, il est nécessaire d'utiliser une étape intermédiaire pour retirer le caractère "£".
#
# Il est possible par exemple d'utiliser l'attribut [.str](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.html) de la série "price".

# %%
# Convertir la colonne price en type décimal
df_books["price"] = 

# Vérification du type de la colonne price
print(df_books["price"].dtype)
# Out:
# float64

# %% [markdown]
# Convertir la colonne `availability` en boolen (True/False).
#
# Afficher d'abord les valeurs possibles de la colonne `availability` en utilisant par exemple la méthode `.value_counts`.

# %%
# Valeurs possibles de la colonne availability
# Out:
# availability
# In stock    1000
# Name: count, dtype: int64

# %% [markdown]
# Créer une fonction qui prend en entrée la valeur de `availability` et qui renvoie True ou False en fonction de la valeur d'entrée.

# %%
# Fonction pour convertir la valeur de availability en booléen
def convert_availability(value):
    """Convert the availability value to a boolean.

    Args:
        value (str): The availability status of the book.

    Returns:
        bool: True if the book is available, False otherwise.
    """
# Out:
# bool

# %% [markdown]
# Utiliser la fonction [`apply`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html) pour appliquer la fonction à la colonne `availability`.

# %%
# Convertir la colonne availability en booléen (True/False)
df_books["availability"] = 

# Vérification du type de la colonne availability
print(df_books["availability"].dtype)

# %% [markdown]
# Convertir la colonne _rating_ en chiffre en utilisant un dictionnaire `rating_map` et la méthode [_map_](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.map.html).

# %%
# Convertir la colonne rating en int
ratings_map = 

df_books["rating"] =

# Vérification du type de la colonne rating
print(df_books["rating"].dtype)
# Out:
# int64

# %% [markdown]
# ---
# ## 2. Création d'une BDD
#
# Création d'une base de données sqlite _livres.db_ (ou connexion à la base si déjà existante).

# %%
# conn : object de connexion à la base de données
conn = sqlite3.connect('book_store.db')

# %% [markdown]
# Écrire la requête SQL qui permet de créer la table `book`.

# %%
# requête SQL pour créer la table book
sql_create_table = '''

'''

# %% [markdown]
# Exécuter la requête en utilisant la méthode `execute` de `conn`.

# %%
# Création de la table

# %% [markdown]
# Chercher et utiliser la méthode pandas qui permet d'écrire les données d'un dataframe dans une BDD SQL.

# %%
# insertion des données dans la table book

# Valider les modifications et fermer la connexion
conn.commit()
conn.close()

# %% [markdown]
# ---
# ## 3. Interroger la BDD en utilisant sqlite3
#
# Utiliser le tuto [sqlite3](https://docs.python.org/3/library/sqlite3.html#sqlite3-tutorial) pour interroger la BDD que vous avez créer dans la partie précédente :
#
# - ouvrir un connexion à la base,
# - utiliser un _cursor_,
# - écrire les requêtes SQL adaptées,
# - éxécuter les requêtes SQL.

# %%
conn = 
cursor =

# %%
# compter le nombre de livres dans la base de données
count = 
print(f"Nombre de livres dans la base de données : {count}")
# Out:
# Nombre de livres dans la base de données : 1000

# %%
# Afficher le nombre total des livres en stock
total_in_stock = 
print(f"Nombre total des livres en stock : {total_in_stock}")
# Out:
# Nombre total des livres en stock : 1000

# %%
# Afficher le nombre de livres avec une note de 5
books_rating_5 = 
print(f"Livres notés 5 : {len(books_rating_5)} livres")

# Afficher la liste de ces livres
# Out:
# Livres notés 5 : 196 livres
# (5, 'Sapiens: A Brief History of Humankind', 54.23, 1, 5)
# (13, 'Set Me Free', 17.46, 1, 5)
# (14, "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 52.29, 1, 5)
# (15, 'Rip it Up and Start Again', 35.02, 1, 5)
# (24, 'Chase Me (Paris Nights #2)', 25.27, 1, 5)
# (25, 'Black Dust', 34.53, 1, 5)
# (29, 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe', 40.3, 1, 5)
# (31, 'The Four Agreements: A Practical Guide to Personal Freedom', 17.66, 1, 5)
# (33, 'The Elephant Tree', 23.82, 1, 5)
# (35, "Sophie's World", 15.94, 1, 5)
# (43, 'Private Paris (Private #10)', 47.61, 1, 5)
# (44, '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.', 23.11, 1, 5)
# (47, 'We Love You, Charlie Freeman', 50.27, 1, 5)
# (55, 'Thirst', 17.27, 1, 5)
# (66, 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer', 20.59, 1, 5)
# (73, "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution", 32.24, 1, 5)
# (81, 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)', 13.61, 1, 5)
# (82, 'Princess Between Worlds (Wide-Awake Princess #5)', 13.34, 1, 5)
# (99, 'Join', 35.67, 1, 5)
# (101, 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine', 57.36, 1, 5)
# (116, 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle', 29.14, 1, 5)
# (123, 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations', 56.76, 1, 5)
# (125, 'A Flight of Arrows (The Pathfinders #2)', 55.53, 1, 5)
# (128, '(Un)Qualified: How God Uses Broken People to Do Big Things', 54, 1, 5)
# (139, 'The Third Wave: An Entrepreneur’s Vision of the Future', 12.61, 1, 5)
# (143, 'The Regional Office Is Under Attack!', 51.36, 1, 5)
# (148, 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us', 37.34, 1, 5)
# (162, "The Artist's Way: A Spiritual Path to Higher Creativity", 38.49, 1, 5)
# (163, 'The Art of War', 33.34, 1, 5)
# (173, 'Scarlett Epstein Hates It Here', 43.55, 1, 5)
# (175, 'Redeeming Love', 20.47, 1, 5)
# (180, 'Mrs. Houdini', 30.25, 1, 5)
# (181, 'Modern Romance', 28.26, 1, 5)
# (185, 'Library of Souls (Miss Peregrine’s Peculiar Children #3)', 48.56, 1, 5)
# (191, 'Frostbite (Vampire Academy #2)', 29.99, 1, 5)
# (194, 'Finders Keepers (Bill Hodges Trilogy #2)', 53.53, 1, 5)
# (198, 'Done Rubbed Out (Reightman & Bailey #1)', 37.72, 1, 5)
# (201, 'Dark Notes', 19.19, 1, 5)
# (209, 'Batman: The Dark Knight Returns (Batman)', 15.38, 1, 5)
# (214, 'Amatus', 50.54, 1, 5)
# (215, 'Agnostic: A Spirited Manifesto', 12.51, 1, 5)
# (217, 'You (You #1)', 43.61, 1, 5)
# (224, "Walt Disney's Alice in Wonderland", 12.96, 1, 5)
# (233, "The White Queen (The Cousins' War #1)", 25.91, 1, 5)
# (235, 'The Time Keeper', 27.88, 1, 5)
# (237, 'The Star-Touched Queen', 46.02, 1, 5)
# (238, 'The Songs of the Gods', 44.48, 1, 5)
# (239, 'The Song of Achilles', 37.4, 1, 5)
# (254, 'The Darkest Lie', 35.35, 1, 5)
# (262, 'Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)', 11.89, 1, 5)
# (264, 'Steve Jobs', 39.5, 1, 5)
# (266, 'Someone Like You (The Harrisons #2)', 52.79, 1, 5)
# (274, 'Quarter Life Poetry: Poems for the Young, Broke and Hangry', 50.89, 1, 5)
# (278, 'Old School (Diary of a Wimpy Kid #10)', 11.83, 1, 5)
# (286, 'Made to Stick: Why Some Ideas Survive and Others Die', 38.85, 1, 5)
# (291, 'Looking for Lovely: Collecting the Moments that Matter', 29.14, 1, 5)
# (293, 'Let It Out: A Journey Through Journaling', 26.79, 1, 5)
# (294, 'Lady Midnight (The Dark Artifices #1)', 16.28, 1, 5)
# (299, 'Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened', 14.75, 1, 5)
# (303, 'Greek Mythic History', 10.23, 1, 5)
# (304, 'God: The Most Unpleasant Character in All Fiction', 30.03, 1, 5)
# (310, 'El Deafo', 57.62, 1, 5)
# (312, 'Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life', 51.75, 1, 5)
# (316, 'Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)', 37.51, 1, 5)
# (317, 'Dear Mr. Knightley', 11.21, 1, 5)
# (332, 'Brain on Fire: My Month of Madness', 49.32, 1, 5)
# (335, "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again", 50.62, 1, 5)
# (341, 'All the Light We Cannot See', 29.87, 1, 5)
# (343, 'Abstract City', 56.37, 1, 5)
# (344, 'A Time of Torment (Charlie Parker #14)', 48.35, 1, 5)
# (359, 'The Star-Touched Queen', 32.3, 1, 5)
# (360, 'The Silent Sister (Riley MacPherson #1)', 46.29, 1, 5)
# (365, 'The Epidemic (The Program 0.6)', 14.44, 1, 5)
# (373, 'Psycho: Sanitarium (Psycho #1.5)', 36.97, 1, 5)
# (380, 'How to Speak Golf: An Illustrated Guide to Links Lingo', 58.32, 1, 5)
# (383, 'Everyday Italian: 125 Simple and Delicious Recipes', 20.1, 1, 5)
# (385, 'Eleanor & Park', 56.51, 1, 5)
# (402, 'Mother, Can You Not?', 16.89, 1, 5)
# (413, 'Born for This: How to Find the Work You Were Meant to Do', 21.59, 1, 5)
# (415, 'Adultery', 20.88, 1, 5)
# (417, "A Gentleman's Position (Society of Gentlemen #3)", 14.75, 1, 5)
# (420, '10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!', 49.71, 1, 5)
# (421, 'Without Shame', 48.27, 1, 5)
# (426, 'The New Brand You: Your New Image Makes the Sale for You', 44.05, 1, 5)
# (431, 'The Art and Science of Low Carbohydrate Living', 52.98, 1, 5)
# (433, 'Suzie Snowflake: One beautiful flake (a self-esteem story)', 54.81, 1, 5)
# (450, 'The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)', 43.62, 1, 5)
# (458, 'Smarter Faster Better: The Secrets of Being Productive in Life and Business', 38.89, 1, 5)
# (460, 'Shadows of the Past (Logan Point #1)', 39.67, 1, 5)
# (461, 'Roller Girl', 14.1, 1, 5)
# (465, 'Out of Print: City Lights Spotlight No. 14', 53.64, 1, 5)
# (466, 'My Life Next Door (My Life Next Door )', 36.39, 1, 5)
# (471, 'Les Fleurs du Mal', 29.04, 1, 5)
# (473, "Kill 'Em and Leave: Searching for James Brown and the American Soul", 45.05, 1, 5)
# (482, 'Future Shock (Future Shock #1)', 55.65, 1, 5)
# (492, '"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination', 44.48, 1, 5)
# (495, 'What Happened on Beale Street (Secrets of the South Mysteries #2)', 25.37, 1, 5)
# (510, "The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)", 52.3, 1, 5)
# (513, 'Team of Rivals: The Political Genius of Abraham Lincoln', 20.12, 1, 5)
# (522, 'Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories', 11.38, 1, 5)
# (527, 'Leave This Song Behind: Teen Poetry at Its Best', 51.17, 1, 5)
# (528, "King's Folly (The Kinsman Chronicles #1)", 39.61, 1, 5)
# (532, 'Good in Bed (Cannie Shapiro #1)', 37.05, 1, 5)
# (536, 'Every Heart a Doorway (Every Heart A Doorway #1)', 12.16, 1, 5)
# (538, 'Counted With the Stars (Out from Egypt #1)', 17.97, 1, 5)
# (542, 'At The Existentialist Café: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others', 29.93, 1, 5)
# (544, 'A Short History of Nearly Everything', 52.4, 1, 5)
# (546, 'The Sound Of Love', 57.84, 1, 5)
# (554, 'The Hobbit (Middle-Earth Universe)', 17.8, 1, 5)
# (560, 'The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)', 15.42, 1, 5)
# (561, 'The Barefoot Contessa Cookbook', 59.92, 1, 5)
# (570, 'How to Stop Worrying and Start Living', 46.49, 1, 5)
# (591, 'The Power Greens Cookbook: 140 Delicious Superfood Recipes', 11.05, 1, 5)
# (593, "The Mathews Men: Seven Brothers and the War Against Hitler's U-boats", 42.91, 1, 5)
# (599, 'The False Prince (The Ascendance Trilogy #1)', 56, 1, 5)
# (602, 'The Darkest Corners', 11.33, 1, 5)
# (608, 'Siddhartha', 34.22, 1, 5)
# (609, 'Shiver (The Wolves of Mercy Falls #1)', 16.23, 1, 5)
# (614, 'Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens', 24.91, 1, 5)
# (620, 'Kill the Boy Band', 15.52, 1, 5)
# (621, 'Isla and the Happily Ever After (Anna and the French Kiss #3)', 48.13, 1, 5)
# (622, 'If I Stay (If I Stay #1)', 38.13, 1, 5)
# (631, 'Dracula the Un-Dead', 35.63, 1, 5)
# (632, 'Digital Fortress', 58, 1, 5)
# (636, 'Booked', 17.49, 1, 5)
# (637, 'Blue Lily, Lily Blue (The Raven Cycle #3)', 34.13, 1, 5)
# (638, 'Approval Junkie: Adventures in Caring Too Much', 58.81, 1, 5)
# (639, 'An Abundance of Katherines', 10, 1, 5)
# (650, 'The Passion of Dolssa', 28.32, 1, 5)
# (652, 'The Hunger Games (The Hunger Games #1)', 29.85, 1, 5)
# (659, 'The Beast (Black Dagger Brotherhood #14)', 46.08, 1, 5)
# (660, 'Some Women', 13.73, 1, 5)
# (661, 'Shopaholic Ties the Knot (Shopaholic #3)', 48.39, 1, 5)
# (662, 'Paper and Fire (The Great Library #2)', 49.45, 1, 5)
# (663, 'Outlander (Outlander #1)', 19.67, 1, 5)
# (665, 'No One Here Gets Out Alive', 20.02, 1, 5)
# (675, 'Harry Potter and the Half-Blood Prince (Harry Potter #6)', 48.75, 1, 5)
# (687, 'Atlas Shrugged', 26.58, 1, 5)
# (690, "A New Earth: Awakening to Your Life's Purpose", 55.65, 1, 5)
# (698, 'When You Are Engulfed in Flames', 30.89, 1, 5)
# (702, 'Voyager (Outlander #3)', 21.07, 1, 5)
# (721, 'The Silkworm (Cormoran Strike #2)', 23.05, 1, 5)
# (722, 'The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3)', 55.55, 1, 5)
# (728, 'The Red Tent', 35.66, 1, 5)
# (736, 'The Nanny Diaries (Nanny #1)', 52.53, 1, 5)
# (740, 'The Lonely Ones', 43.59, 1, 5)
# (745, "The Husband's Secret", 52.51, 1, 5)
# (757, 'The Disappearing Spoon: And Other True Tales of Madness, Love, and the History of the World from the Periodic Table of the Elements', 57.35, 1, 5)
# (760, 'The Day the Crayons Came Home (Crayons)', 26.33, 1, 5)
# (764, 'The Complete Poems', 41.32, 1, 5)
# (769, 'The Book of Basketball: The NBA According to The Sports Guy', 44.84, 1, 5)
# (770, 'The Blind Side: Evolution of a Game', 53.71, 1, 5)
# (777, 'Something Borrowed (Darcy & Rachel #1)', 48.96, 1, 5)
# (785, 'Saga, Volume 3 (Saga (Collected Editions) #3)', 21.57, 1, 5)
# (813, 'Life Without a Recipe', 59.04, 1, 5)
# (819, "Lamb: The Gospel According to Biff, Christ's Childhood Pal", 55.5, 1, 5)
# (820, 'Lady Renegades (Rebel Belle #3)', 53.04, 1, 5)
# (824, 'Into the Wild', 56.7, 1, 5)
# (825, 'Inferno (Robert Langdon #4)', 41, 1, 5)
# (838, 'Gratitude', 26.66, 1, 5)
# (839, 'Gone Girl', 37.6, 1, 5)
# (845, 'Fifty Shades Freed (Fifty Shades #3)', 15.36, 1, 5)
# (853, 'Disrupted: My Misadventure in the Start-Up Bubble', 15.28, 1, 5)
# (854, 'Dead Wake: The Last Crossing of the Lusitania', 39.24, 1, 5)
# (857, 'Dark Places', 23.9, 1, 5)
# (858, 'Crazy Rich Asians (Crazy Rich Asians #1)', 49.13, 1, 5)
# (865, 'Breaking Dawn (Twilight #4)', 35.28, 1, 5)
# (866, 'Brave Enough', 51.32, 1, 5)
# (869, 'Blink: The Power of Thinking Without Thinking', 21.74, 1, 5)
# (873, 'Between Shades of Gray', 20.79, 1, 5)
# (876, 'Beautiful Creatures (Caster Chronicles #1)', 21.55, 1, 5)
# (881, 'Annie on My Mind', 36.83, 1, 5)
# (884, 'A Visit from the Goon Squad', 14.08, 1, 5)
# (886, 'A Heartbreaking Work of Staggering Genius', 54.29, 1, 5)
# (897, 'Life', 31.58, 1, 5)
# (899, 'H is for Hawk', 57.42, 1, 5)
# (901, 'Fruits Basket, Vol. 2 (Fruits Basket #2)', 11.64, 1, 5)
# (904, 'While You Were Mine', 41.32, 1, 5)
# (907, 'Ways of Seeing', 39.51, 1, 5)
# (911, 'Travels with Charley: In Search of America', 57.82, 1, 5)
# (914, 'The Zombie Room', 19.69, 1, 5)
# (916, 'The Tumor', 41.56, 1, 5)
# (918, 'The Silent Wife', 12.34, 1, 5)
# (933, 'The Hook Up (Game On #1)', 36.29, 1, 5)
# (934, 'The Haters', 27.89, 1, 5)
# (935, 'The Girl You Lost', 12.29, 1, 5)
# (955, 'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)', 46.96, 1, 5)
# (963, 'Off Sides (Off #1)', 39.45, 1, 5)
# (973, 'Kitchens of the Great Midwest', 57.2, 1, 5)
# (974, 'Jane Eyre', 38.43, 1, 5)
# (980, 'Fruits Basket, Vol. 1 (Fruits Basket #1)', 40.28, 1, 5)
# (986, 'Deep Under (Walker Security #1)', 47.09, 1, 5)
# (990, 'Bright Lines', 39.07, 1, 5)
# (994, 'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)', 34.65, 1, 5)
# (998, "A Spy's Devotion (The Regency Spies of London #1)", 16.97, 1, 5)
# (1000, '1,000 Places to See Before You Die', 26.08, 1, 5)

# %%
# Afficher le nombre de livres avec une note de 4 ou plus
books_rating_4_plus = 
print(f"Livres notés 4 ou plus triés par prix décroissant : {len(books_rating_4_plus)} livres")

# Afficher la liste de ces livres par ordre décroissant de prix
# Out:
# Livres notés 4 ou plus triés par prix décroissant : 375 livres
# (561, 'The Barefoot Contessa Cookbook', 59.92, 1, 5)
# (550, 'The Man Who Mistook His Wife for a Hat and Other Clinical Tales', 59.45, 1, 4)
# (363, 'The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore', 59.15, 1, 4)
# (813, 'Life Without a Recipe', 59.04, 1, 5)
# (423, 'Unlimited Intuition Now', 58.87, 1, 4)
# (638, 'Approval Junkie: Adventures in Caring Too Much', 58.81, 1, 5)
# (965, 'Myriad (Prentor #1)', 58.75, 1, 4)
# (723, 'The Rose & the Dagger (The Wrath and the Dawn #2)', 58.64, 1, 4)
# (641, 'Alight (The Generations Trilogy #2)', 58.59, 1, 4)
# (577, 'Catherine the Great: Portrait of a Woman', 58.55, 1, 4)
# (380, 'How to Speak Golf: An Illustrated Guide to Links Lingo', 58.32, 1, 5)
# (338, 'Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)', 58.14, 1, 4)
# (69, 'The Death of Humanity: and the Case for Life', 58.11, 1, 4)
# (136, 'The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”', 58.08, 1, 4)
# (422, 'Watchmen', 58.05, 1, 4)
# (632, 'Digital Fortress', 58, 1, 5)
# (546, 'The Sound Of Love', 57.84, 1, 5)
# (911, 'Travels with Charley: In Search of America', 57.82, 1, 5)
# (590, 'The Raven Boys (The Raven Cycle #1)', 57.74, 1, 4)
# (925, "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)", 57.7, 1, 4)
# (310, 'El Deafo', 57.62, 1, 5)
# (529, 'John Adams', 57.43, 1, 4)
# (899, 'H is for Hawk', 57.42, 1, 5)
# (101, 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine', 57.36, 1, 5)
# (187, 'I Had a Nice Time And Other Lies...: How to find love & sh*t like that', 57.36, 1, 4)
# (757, 'The Disappearing Spoon: And Other True Tales of Madness, Love, and the History of the World from the Periodic Table of the Elements', 57.35, 1, 5)
# (973, 'Kitchens of the Great Midwest', 57.2, 1, 5)
# (997, 'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)', 57.06, 1, 4)
# (488, 'Between the World and Me', 56.91, 1, 4)
# (580, 'A Year in Provence (Provence #1)', 56.88, 1, 4)
# (232, 'The Wright Brothers', 56.8, 1, 4)
# (123, 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations', 56.76, 1, 5)
# (979, 'Giant Days, Vol. 1 (Giant Days #1-4)', 56.76, 1, 4)
# (824, 'Into the Wild', 56.7, 1, 5)
# (573, 'Fun Home: A Family Tragicomic', 56.59, 1, 4)
# (385, 'Eleanor & Park', 56.51, 1, 5)
# (59, 'The Past Never Ends', 56.5, 1, 4)
# (343, 'Abstract City', 56.37, 1, 5)
# (323, 'City of Glass (The Mortal Instruments #3)', 56.02, 1, 4)
# (599, 'The False Prince (The Ascendance Trilogy #1)', 56, 1, 5)
# (595, 'The Hiding Place', 55.91, 1, 4)
# (268, 'Shtum', 55.84, 1, 4)
# (482, 'Future Shock (Future Shock #1)', 55.65, 1, 5)
# (690, "A New Earth: Awakening to Your Life's Purpose", 55.65, 1, 5)
# (722, 'The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3)', 55.55, 1, 5)
# (125, 'A Flight of Arrows (The Pathfinders #2)', 55.53, 1, 5)
# (819, "Lamb: The Gospel According to Biff, Christ's Childhood Pal", 55.5, 1, 5)
# (489, 'Being Mortal: Medicine and What Matters in the End', 55.06, 1, 4)
# (433, 'Suzie Snowflake: One beautiful flake (a self-esteem story)', 54.81, 1, 5)
# (376, 'No Love Allowed (Dodge Cove #1)', 54.65, 1, 4)
# (196, 'Eureka Trivia 6.0', 54.59, 1, 4)
# (377, 'Murder at the 42nd Street Library (Raymond Ambler #1)', 54.36, 1, 4)
# (886, 'A Heartbreaking Work of Staggering Genius', 54.29, 1, 5)
# (5, 'Sapiens: A Brief History of Humankind', 54.23, 1, 5)
# (128, '(Un)Qualified: How God Uses Broken People to Do Big Things', 54, 1, 5)
# (770, 'The Blind Side: Evolution of a Game', 53.71, 1, 5)
# (585, 'What If?: Serious Scientific Answers to Absurd Hypothetical Questions', 53.68, 1, 4)
# (465, 'Out of Print: City Lights Spotlight No. 14', 53.64, 1, 5)
# (194, 'Finders Keepers (Bill Hodges Trilogy #2)', 53.53, 1, 5)
# (820, 'Lady Renegades (Rebel Belle #3)', 53.04, 1, 5)
# (431, 'The Art and Science of Low Carbohydrate Living', 52.98, 1, 5)
# (902, 'Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)', 52.88, 1, 4)
# (266, 'Someone Like You (The Harrisons #2)', 52.79, 1, 5)
# (236, 'The Testament of Mary', 52.67, 1, 4)
# (220, 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond', 52.65, 1, 4)
# (736, 'The Nanny Diaries (Nanny #1)', 52.53, 1, 5)
# (745, "The Husband's Secret", 52.51, 1, 5)
# (544, 'A Short History of Nearly Everything', 52.4, 1, 5)
# (646, 'Vogue Colors A to Z: A Fashion Coloring Book', 52.35, 1, 4)
# (510, "The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)", 52.3, 1, 5)
# (14, "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 52.29, 1, 5)
# (759, 'The Demon-Haunted World: Science as a Candle in the Dark', 52.25, 1, 4)
# (39, 'Behind Closed Doors', 52.22, 1, 4)
# (112, 'Danganronpa Volume 1', 51.99, 1, 4)
# (312, 'Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life', 51.75, 1, 5)
# (143, 'The Regional Office Is Under Attack!', 51.36, 1, 5)
# (410, 'Exit, Pursued by a Bear', 51.34, 1, 4)
# (866, 'Brave Enough', 51.32, 1, 5)
# (527, 'Leave This Song Behind: Teen Poetry at Its Best', 51.17, 1, 5)
# (274, 'Quarter Life Poetry: Poems for the Young, Broke and Hangry', 50.89, 1, 5)
# (335, "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again", 50.62, 1, 5)
# (214, 'Amatus', 50.54, 1, 5)
# (680, 'Fruits Basket, Vol. 4 (Fruits Basket #4)', 50.44, 1, 4)
# (521, 'Nightstruck: A Novel', 50.35, 1, 4)
# (47, 'We Love You, Charlie Freeman', 50.27, 1, 5)
# (569, 'In Cold Blood', 49.98, 1, 4)
# (827, 'If I Run (If I Run #1)', 49.97, 1, 4)
# (420, '10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!', 49.71, 1, 5)
# (371, 'Raspberry Pi Electronics Projects for the Evil Genius', 49.67, 1, 4)
# (692, "'Salem's Lot", 49.56, 1, 4)
# (203, 'Close to You', 49.46, 1, 4)
# (662, 'Paper and Fire (The Great Library #2)', 49.45, 1, 5)
# (190, 'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond', 49.43, 1, 4)
# (332, 'Brain on Fire: My Month of Madness', 49.32, 1, 5)
# (858, 'Crazy Rich Asians (Crazy Rich Asians #1)', 49.13, 1, 5)
# (777, 'Something Borrowed (Darcy & Rachel #1)', 48.96, 1, 5)
# (675, 'Harry Potter and the Half-Blood Prince (Harry Potter #6)', 48.75, 1, 5)
# (442, 'Art and Fear: Observations on the Perils (and Rewards) of Artmaking', 48.63, 1, 4)
# (185, 'Library of Souls (Miss Peregrine’s Peculiar Children #3)', 48.56, 1, 5)
# (409, 'Grey (Fifty Shades #4)', 48.49, 1, 4)
# (661, 'Shopaholic Ties the Knot (Shopaholic #3)', 48.39, 1, 5)
# (344, 'A Time of Torment (Charlie Parker #14)', 48.35, 1, 5)
# (421, 'Without Shame', 48.27, 1, 5)
# (621, 'Isla and the Happily Ever After (Anna and the French Kiss #3)', 48.13, 1, 5)
# (4, 'Sharp Objects', 47.82, 1, 4)
# (43, 'Private Paris (Private #10)', 47.61, 1, 5)
# (667, 'Needful Things', 47.51, 1, 4)
# (582, 'Will Grayson, Will Grayson (Will Grayson, Will Grayson)', 47.31, 1, 4)
# (986, 'Deep Under (Walker Security #1)', 47.09, 1, 5)
# (955, 'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)', 46.96, 1, 5)
# (292, 'Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments', 46.91, 1, 4)
# (211, 'Anonymous', 46.82, 1, 4)
# (270, 'salt.', 46.78, 1, 4)
# (570, 'How to Stop Worrying and Start Living', 46.49, 1, 5)
# (360, 'The Silent Sister (Riley MacPherson #1)', 46.29, 1, 5)
# (659, 'The Beast (Black Dagger Brotherhood #14)', 46.08, 1, 5)
# (237, 'The Star-Touched Queen', 46.02, 1, 5)
# (530, 'How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)', 46.01, 1, 4)
# (715, 'The Undomestic Goddess', 45.75, 1, 4)
# (473, "Kill 'Em and Leave: Searching for James Brown and the American Soul", 45.05, 1, 5)
# (769, 'The Book of Basketball: The NBA According to The Sports Guy', 44.84, 1, 5)
# (545, 'A Gathering of Shadows (Shades of Magic #2)', 44.81, 1, 4)
# (265, 'Sorting the Beef from the Bull: The Science of Food Fraud Forensics', 44.74, 1, 4)
# (255, 'The Bane Chronicles (The Bane Chronicles #1-11)', 44.73, 1, 4)
# (238, 'The Songs of the Gods', 44.48, 1, 5)
# (492, '"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination', 44.48, 1, 5)
# (30, 'Wall and Piece', 44.18, 1, 4)
# (49, 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness', 44.18, 1, 4)
# (149, 'The Murder of Roger Ackroyd (Hercule Poirot #4)', 44.1, 1, 4)
# (835, 'Heir to the Sky', 44.07, 1, 4)
# (426, 'The New Brand You: Your New Image Makes the Sale for You', 44.05, 1, 5)
# (817, 'Legend (Legend #1)', 43.69, 1, 4)
# (450, 'The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)', 43.62, 1, 5)
# (217, 'You (You #1)', 43.61, 1, 5)
# (740, 'The Lonely Ones', 43.59, 1, 5)
# (173, 'Scarlett Epstein Hates It Here', 43.55, 1, 5)
# (130, "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)", 43.3, 1, 4)
# (552, 'The Joy of Cooking', 43.27, 1, 4)
# (917, 'The Story of Hong Gildong', 43.19, 1, 4)
# (63, "The Most Perfect Thing: Inside (and Outside) a Bird's Egg", 42.96, 1, 4)
# (593, "The Mathews Men: Seven Brothers and the War Against Hitler's U-boats", 42.91, 1, 5)
# (509, 'The Bourne Identity (Jason Bourne #1)', 42.78, 1, 4)
# (840, 'Golden (Heart of Dread #3)', 42.21, 1, 4)
# (138, 'The Vacationers', 42.15, 1, 4)
# (74, 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up', 41.83, 1, 4)
# (154, 'The Kite Runner', 41.82, 1, 4)
# (584, 'Where She Went (If I Stay #2)', 41.73, 1, 4)
# (788, 'Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars', 41.67, 1, 4)
# (195, 'Fables, Vol. 1: Legends in Exile (Fables #1)', 41.62, 1, 4)
# (916, 'The Tumor', 41.56, 1, 5)
# (382, 'Furiously Happy: A Funny Book About Horrible Things', 41.46, 1, 4)
# (764, 'The Complete Poems', 41.32, 1, 5)
# (904, 'While You Were Mine', 41.32, 1, 5)
# (501, 'The Story of Art', 41.14, 1, 4)
# (825, 'Inferno (Robert Langdon #4)', 41, 1, 5)
# (386, 'Dirty (Dive Bar #1)', 40.83, 1, 4)
# (943, 'The Art of Not Breathing', 40.83, 1, 4)
# (976, 'Icing (Aces Hockey #2)', 40.44, 1, 4)
# (575, 'Deception Point', 40.32, 1, 4)
# (29, 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe', 40.3, 1, 5)
# (980, 'Fruits Basket, Vol. 1 (Fruits Basket #1)', 40.28, 1, 5)
# (516, 'Sister Dear', 40.2, 1, 4)
# (460, 'Shadows of the Past (Logan Point #1)', 39.67, 1, 5)
# (528, "King's Folly (The Kinsman Chronicles #1)", 39.61, 1, 5)
# (907, 'Ways of Seeing', 39.51, 1, 5)
# (264, 'Steve Jobs', 39.5, 1, 5)
# (963, 'Off Sides (Off #1)', 39.45, 1, 5)
# (967, 'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)', 39.39, 1, 4)
# (854, 'Dead Wake: The Last Crossing of the Lusitania', 39.24, 1, 5)
# (990, 'Bright Lines', 39.07, 1, 5)
# (389, 'A Paris Apartment', 39.01, 1, 4)
# (458, 'Smarter Faster Better: The Secrets of Being Productive in Life and Business', 38.89, 1, 5)
# (286, 'Made to Stick: Why Some Ideas Survive and Others Die', 38.85, 1, 5)
# (603, 'The Crossover', 38.77, 1, 4)
# (162, "The Artist's Way: A Spiritual Path to Higher Creativity", 38.49, 1, 5)
# (974, 'Jane Eyre', 38.43, 1, 5)
# (221, 'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity', 38.2, 1, 4)
# (61, 'The Nameless City (The Nameless City #1)', 38.16, 1, 4)
# (622, 'If I Stay (If I Stay #1)', 38.13, 1, 5)
# (354, 'Rook', 37.86, 1, 4)
# (331, 'Buying In: The Secret Dialogue Between What We Buy and Who We Are', 37.8, 1, 4)
# (198, 'Done Rubbed Out (Reightman & Bailey #1)', 37.72, 1, 5)
# (839, 'Gone Girl', 37.6, 1, 5)
# (316, 'Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)', 37.51, 1, 5)
# (485, 'Death by Leisure: A Cautionary Tale', 37.51, 1, 4)
# (239, 'The Song of Achilles', 37.4, 1, 5)
# (148, 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us', 37.34, 1, 5)
# (218, 'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)', 37.34, 1, 4)
# (992, 'Bounty (Colorado Mountain #7)', 37.26, 1, 4)
# (225, 'V for Vendetta (V for Vendetta Complete)', 37.1, 1, 4)
# (532, 'Good in Bed (Cannie Shapiro #1)', 37.05, 1, 5)
# (373, 'Psycho: Sanitarium (Psycho #1.5)', 36.97, 1, 5)
# (881, 'Annie on My Mind', 36.83, 1, 5)
# (114, 'Codename Baboushka, Volume 1: The Conclave of Death', 36.72, 1, 4)
# (466, 'My Life Next Door (My Life Next Door )', 36.39, 1, 5)
# (933, 'The Hook Up (Game On #1)', 36.29, 1, 5)
# (503, 'The Great Gatsby', 36.05, 1, 4)
# (500, 'The Whale', 35.96, 1, 4)
# (99, 'Join', 35.67, 1, 5)
# (728, 'The Red Tent', 35.66, 1, 5)
# (631, 'Dracula the Un-Dead', 35.63, 1, 5)
# (267, 'So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)', 35.43, 1, 4)
# (254, 'The Darkest Lie', 35.35, 1, 5)
# (865, 'Breaking Dawn (Twilight #4)', 35.28, 1, 5)
# (15, 'Rip it Up and Start Again', 35.02, 1, 5)
# (978, "Having the Barbarian's Baby (Ice Planet Barbarians #7.5)", 34.96, 1, 4)
# (197, 'Drive: The Surprising Truth About What Motivates Us', 34.95, 1, 4)
# (975, 'Imperfect Harmony', 34.74, 1, 4)
# (994, 'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)', 34.65, 1, 5)
# (25, 'Black Dust', 34.53, 1, 5)
# (608, 'Siddhartha', 34.22, 1, 5)
# (637, 'Blue Lily, Lily Blue (The Raven Cycle #3)', 34.13, 1, 5)
# (438, 'Fruits Basket, Vol. 9 (Fruits Basket #9)', 33.95, 1, 4)
# (7, 'The Dirty Little Secrets of Getting Your Dream Job', 33.34, 1, 4)
# (163, 'The Art of War', 33.34, 1, 5)
# (512, 'The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change', 33.17, 1, 4)
# (581, 'World Without End (The Pillars of the Earth #2)', 32.97, 1, 4)
# (359, 'The Star-Touched Queen', 32.3, 1, 5)
# (73, "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution", 32.24, 1, 5)
# (613, 'My Mother Was Nuts', 31.63, 1, 4)
# (674, 'Harry Potter and the Order of the Phoenix (Harry Potter #5)', 31.63, 1, 4)
# (897, 'Life', 31.58, 1, 5)
# (619, 'Killing Floor (Jack Reacher #1)', 31.49, 1, 4)
# (464, 'Please Kill Me: The Uncensored Oral History of Punk', 31.19, 1, 4)
# (910, 'Twenty Love Poems and a Song of Despair', 30.95, 1, 4)
# (698, 'When You Are Engulfed in Flames', 30.89, 1, 5)
# (782, 'Seven Brief Lessons on Physics', 30.6, 1, 4)
# (883, 'A Walk in the Woods: Rediscovering America on the Appalachian Trail', 30.48, 1, 4)
# (180, 'Mrs. Houdini', 30.25, 1, 5)
# (304, 'God: The Most Unpleasant Character in All Fiction', 30.03, 1, 5)
# (191, 'Frostbite (Vampire Academy #2)', 29.99, 1, 5)
# (542, 'At The Existentialist Café: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others', 29.93, 1, 5)
# (341, 'All the Light We Cannot See', 29.87, 1, 5)
# (652, 'The Hunger Games (The Hunger Games #1)', 29.85, 1, 5)
# (743, 'The Land of 10,000 Madonnas', 29.64, 1, 4)
# (116, 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle', 29.14, 1, 5)
# (291, 'Looking for Lovely: Collecting the Moments that Matter', 29.14, 1, 5)
# (471, 'Les Fleurs du Mal', 29.04, 1, 5)
# (452, "The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer", 28.45, 1, 4)
# (987, "Choosing Our Religion: The Spiritual Lives of America's Nones", 28.42, 1, 4)
# (650, 'The Passion of Dolssa', 28.32, 1, 5)
# (181, 'Modern Romance', 28.26, 1, 5)
# (126, 'A Fierce and Subtle Poison', 28.13, 1, 4)
# (242, 'The Marriage of Opposites', 28.08, 1, 4)
# (670, 'Little Women (Little Women #1)', 28.07, 1, 4)
# (934, 'The Haters', 27.89, 1, 5)
# (235, 'The Time Keeper', 27.88, 1, 5)
# (970, 'Lost Among the Living', 27.7, 1, 4)
# (142, 'The Secret (The Secret #1)', 27.37, 1, 4)
# (293, 'Let It Out: A Journey Through Journaling', 26.79, 1, 5)
# (763, 'The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition])', 26.78, 1, 4)
# (838, 'Gratitude', 26.66, 1, 5)
# (687, 'Atlas Shrugged', 26.58, 1, 5)
# (760, 'The Day the Crayons Came Home (Crayons)', 26.33, 1, 5)
# (734, 'The Nightingale', 26.26, 1, 4)
# (1000, '1,000 Places to See Before You Die', 26.08, 1, 5)
# (297, "I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction", 25.98, 1, 4)
# (233, "The White Queen (The Cousins' War #1)", 25.91, 1, 5)
# (495, 'What Happened on Beale Street (Secrets of the South Mysteries #2)', 25.37, 1, 5)
# (24, 'Chase Me (Paris Nights #2)', 25.27, 1, 5)
# (607, "Talking to Girls About Duran Duran: One Young Man's Quest for True Love and a Cooler Haircut", 25.15, 1, 4)
# (614, 'Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens', 24.91, 1, 5)
# (549, 'The Mysterious Affair at Styles (Hercule Poirot #1)', 24.8, 1, 4)
# (673, 'Harry Potter and the Prisoner of Azkaban (Harry Potter #3)', 24.17, 1, 4)
# (857, 'Dark Places', 23.9, 1, 5)
# (64, 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy', 23.89, 1, 4)
# (33, 'The Elephant Tree', 23.82, 1, 5)
# (616, 'Lola and the Boy Next Door (Anna and the French Kiss #2)', 23.63, 1, 4)
# (44, '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.', 23.11, 1, 5)
# (721, 'The Silkworm (Cormoran Strike #2)', 23.05, 1, 5)
# (9, 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 22.6, 1, 4)
# (321, 'Code Name Verity (Code Name Verity #1)', 22.13, 1, 4)
# (755, 'The End of Faith: Religion, Terror, and the Future of Reason', 22.13, 1, 4)
# (878, 'Ash', 22.06, 1, 4)
# (100, 'In the Country We Love: My Family Divided', 22, 1, 4)
# (478, 'Hystopia: A Novel', 21.96, 1, 4)
# (129, 'You Are What You Love: The Spiritual Power of Habit', 21.87, 1, 4)
# (869, 'Blink: The Power of Thinking Without Thinking', 21.74, 1, 5)
# (950, 'Shadow Rites (Jane Yellowrock #10)', 21.72, 1, 4)
# (957, 'Paper Girls, Vol. 1 (Paper Girls #1-5)', 21.71, 1, 4)
# (413, 'Born for This: How to Find the Work You Were Meant to Do', 21.59, 1, 5)
# (785, 'Saga, Volume 3 (Saga (Collected Editions) #3)', 21.57, 1, 5)
# (876, 'Beautiful Creatures (Caster Chronicles #1)', 21.55, 1, 5)
# (414, 'Arena', 21.36, 1, 4)
# (844, 'Fire Bound (Sea Haven/Sisters of the Heart #5)', 21.28, 1, 4)
# (702, 'Voyager (Outlander #3)', 21.07, 1, 5)
# (574, 'Fruits Basket, Vol. 6 (Fruits Basket #6)', 20.96, 1, 4)
# (537, 'Delivering the Truth (Quaker Midwife Mystery #1)', 20.89, 1, 4)
# (415, 'Adultery', 20.88, 1, 5)
# (873, 'Between Shades of Gray', 20.79, 1, 5)
# (12, "Shakespeare's Sonnets", 20.66, 1, 4)
# (66, 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer', 20.59, 1, 5)
# (175, 'Redeeming Love', 20.47, 1, 5)
# (407, 'Keep Me Posted', 20.46, 1, 4)
# (668, 'Mockingjay (The Hunger Games #3)', 20.44, 1, 4)
# (327, 'Cell', 20.29, 1, 4)
# (475, 'John Vassos: Industrial Design for Modern Life', 20.22, 1, 4)
# (513, 'Team of Rivals: The Political Genius of Abraham Lincoln', 20.12, 1, 5)
# (383, 'Everyday Italian: 125 Simple and Delicious Recipes', 20.1, 1, 5)
# (665, 'No One Here Gets Out Alive', 20.02, 1, 5)
# (914, 'The Zombie Room', 19.69, 1, 5)
# (663, 'Outlander (Outlander #1)', 19.67, 1, 5)
# (54, 'This One Summer', 19.49, 1, 4)
# (564, 'Pride and Prejudice', 19.27, 1, 4)
# (201, 'Dark Notes', 19.19, 1, 5)
# (938, 'The Edge of Reason (Bridget Jones #2)', 19.18, 1, 4)
# (792, 'Ready Player One', 19.07, 1, 4)
# (903, 'Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)', 18.51, 1, 4)
# (538, 'Counted With the Stars (Out from Egypt #1)', 17.97, 1, 5)
# (554, 'The Hobbit (Middle-Earth Universe)', 17.8, 1, 5)
# (31, 'The Four Agreements: A Practical Guide to Personal Freedom', 17.66, 1, 5)
# (636, 'Booked', 17.49, 1, 5)
# (13, 'Set Me Free', 17.46, 1, 5)
# (140, 'The Stranger', 17.44, 1, 4)
# (55, 'Thirst', 17.27, 1, 5)
# (644, 'A Feast for Crows (A Song of Ice and Fire #4)', 17.21, 1, 4)
# (115, 'Camp Midnight', 17.08, 1, 4)
# (998, "A Spy's Devotion (The Regency Spies of London #1)", 16.97, 1, 5)
# (402, 'Mother, Can You Not?', 16.89, 1, 5)
# (654, 'The Gunning of America: Business and the Making of American Gun Culture', 16.81, 1, 4)
# (294, 'Lady Midnight (The Dark Artifices #1)', 16.28, 1, 5)
# (167, 'Something More Than This', 16.24, 1, 4)
# (609, 'Shiver (The Wolves of Mercy Falls #1)', 16.23, 1, 5)
# (108, 'First and First (Five Boroughs #3)', 15.97, 1, 4)
# (35, "Sophie's World", 15.94, 1, 5)
# (375, 'One with You (Crossfire #5)', 15.71, 1, 4)
# (620, 'Kill the Boy Band', 15.52, 1, 5)
# (86, 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)', 15.44, 1, 4)
# (560, 'The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)', 15.42, 1, 5)
# (209, 'Batman: The Dark Knight Returns (Batman)', 15.38, 1, 5)
# (845, 'Fifty Shades Freed (Fifty Shades #3)', 15.36, 1, 5)
# (853, 'Disrupted: My Misadventure in the Start-Up Bubble', 15.28, 1, 5)
# (588, 'The Secret Garden', 15.08, 1, 4)
# (307, 'Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years', 15.06, 1, 4)
# (299, 'Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened', 14.75, 1, 5)
# (417, "A Gentleman's Position (Society of Gentlemen #3)", 14.75, 1, 5)
# (783, 'Scarlet (The Lunar Chronicles #2)', 14.57, 1, 4)
# (365, 'The Epidemic (The Program 0.6)', 14.44, 1, 5)
# (311, 'Eight Hundred Grapes', 14.39, 1, 4)
# (48, 'Untitled Collection: Sabbath Poems 2014', 14.27, 1, 4)
# (177, 'Poems That Make Grown Women Cry', 14.19, 1, 4)
# (461, 'Roller Girl', 14.1, 1, 5)
# (884, 'A Visit from the Goon Squad', 14.08, 1, 5)
# (93, 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed', 14.02, 1, 4)
# (660, 'Some Women', 13.73, 1, 5)
# (81, 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)', 13.61, 1, 5)
# (82, 'Princess Between Worlds (Wide-Awake Princess #5)', 13.34, 1, 5)
# (526, 'Life of Pi', 13.22, 1, 4)
# (756, 'The Elegant Universe: Superstrings, Hidden Dimensions, and the Quest for the Ultimate Theory', 13.03, 1, 4)
# (224, "Walt Disney's Alice in Wonderland", 12.96, 1, 5)
# (786, 'Running with Scissors', 12.91, 1, 4)
# (896, 'New Moon (Twilight #2)', 12.86, 1, 4)
# (666, 'Night Shift (Night Shift #1-20)', 12.75, 1, 4)
# (139, 'The Third Wave: An Entrepreneur’s Vision of the Future', 12.61, 1, 5)
# (215, 'Agnostic: A Spirited Manifesto', 12.51, 1, 5)
# (427, 'The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York', 12.34, 1, 4)
# (918, 'The Silent Wife', 12.34, 1, 5)
# (935, 'The Girl You Lost', 12.29, 1, 5)
# (536, 'Every Heart a Doorway (Every Heart A Doorway #1)', 12.16, 1, 5)
# (262, 'Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)', 11.89, 1, 5)
# (278, 'Old School (Diary of a Wimpy Kid #10)', 11.83, 1, 5)
# (393, 'The Sleep Revolution: Transforming Your Life, One Night at a Time', 11.68, 1, 4)
# (901, 'Fruits Basket, Vol. 2 (Fruits Basket #2)', 11.64, 1, 5)
# (522, 'Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories', 11.38, 1, 5)
# (602, 'The Darkest Corners', 11.33, 1, 5)
# (324, 'City of Fallen Angels (The Mortal Instruments #4)', 11.23, 1, 4)
# (317, 'Dear Mr. Knightley', 11.21, 1, 5)
# (591, 'The Power Greens Cookbook: 140 Delicious Superfood Recipes', 11.05, 1, 5)
# (836, 'Green Eggs and Ham (Beginner Books B-16)', 10.79, 1, 4)
# (298, 'I Am Pilgrim (Pilgrim #1)', 10.6, 1, 4)
# (435, 'NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond', 10.41, 1, 4)
# (480, 'History of Beauty', 10.29, 1, 4)
# (303, 'Greek Mythic History', 10.23, 1, 5)
# (502, 'The Origin of Species', 10.01, 1, 4)
# (639, 'An Abundance of Katherines', 10, 1, 5)

# %%
# Note moyenne des livres disponibles
average_rating =
print(f"Note moyenne des livres disponibles : {average_rating:.2f}")
# Out:
# Note moyenne des livres disponibles : 2.92

# %%
# Afficher les prix max et min des livres
max_price = 
min_price =
print(f"Prix maximum : {max_price}, Prix minimum : {min_price}")
# Out:
# Prix maximum : 59.99, Prix minimum : 10

# %%
# Afficher le prix moyen des livres
average_price = 
print(f"Prix moyen des livres : {average_price}")
# Out:
# Prix moyen des livres : 35.07035

# %%
# Afficher le nombre de livres par note
# Out:
# Nombre de livres par note :
# - 5 étoiles : 196 livres
# - 4 étoiles : 179 livres
# - 3 étoiles : 203 livres
# - 2 étoiles : 196 livres
# - 1 étoiles : 226 livres

# %%
# Afficher les livres qui coûtent plus cher que la moyenne
# Out:
# Livres plus chers que la moyenne (35.07035) : 513
# (1, 'A Light in the Attic', 51.77, 1, 3)
# (2, 'Tipping the Velvet', 53.74, 1, 1)
# (3, 'Soumission', 50.1, 1, 1)
# (4, 'Sharp Objects', 47.82, 1, 4)
# (5, 'Sapiens: A Brief History of Humankind', 54.23, 1, 5)
# (10, 'The Black Maria', 52.15, 1, 1)
# (14, "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 52.29, 1, 5)
# (16, 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 57.25, 1, 3)
# (18, 'Mesaerion: The Best Science Fiction Stories 1800-1849', 37.59, 1, 1)
# (19, 'Libertarianism for Beginners', 51.33, 1, 2)
# (20, "It's Only the Himalayas", 45.17, 1, 2)
# (22, 'How Music Works', 37.32, 1, 2)
# (26, 'Birdsong: A Story in Pictures', 54.64, 1, 3)
# (28, 'Aladdin and His Wonderful Lamp', 53.13, 1, 3)
# (29, 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe', 40.3, 1, 5)
# (30, 'Wall and Piece', 44.18, 1, 4)
# (34, 'The Bear and the Piano', 36.89, 1, 1)
# (39, 'Behind Closed Doors', 52.22, 1, 4)
# (41, 'Slow States of Collapse: Poems', 57.31, 1, 3)
# (43, 'Private Paris (Private #10)', 47.61, 1, 5)
# (45, 'Without Borders (Wanderlove #1)', 45.07, 1, 2)
# (47, 'We Love You, Charlie Freeman', 50.27, 1, 5)
# (49, 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness', 44.18, 1, 4)
# (57, 'The Secret of Dreadwillow Carse', 56.13, 1, 1)
# (58, 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!', 56.41, 1, 1)
# (59, 'The Past Never Ends', 56.5, 1, 4)
# (60, 'The Natural History of Us (The Fine Art of Pretending #2)', 45.22, 1, 3)
# (61, 'The Nameless City (The Nameless City #1)', 38.16, 1, 4)
# (62, 'The Murder That Never Was (Forensic Instincts #5)', 54.11, 1, 3)
# (63, "The Most Perfect Thing: Inside (and Outside) a Bird's Egg", 42.96, 1, 4)
# (67, 'The Gutsy Girl: Escapades for Your Life of Epic Adventure', 37.13, 1, 1)
# (68, 'The Electric Pencil: Drawings from Inside State Hospital No. 3', 56.06, 1, 1)
# (69, 'The Death of Humanity: and the Case for Life', 58.11, 1, 4)
# (70, 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life', 49.05, 1, 3)
# (71, 'The Art Forger', 40.76, 1, 3)
# (74, 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up', 41.83, 1, 4)
# (75, 'Soul Reader', 39.58, 1, 2)
# (76, 'Security', 39.25, 1, 2)
# (78, 'Saga, Volume 5 (Saga (Collected Editions) #5)', 51.04, 1, 2)
# (80, 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)', 50.4, 1, 3)
# (84, 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics', 36.28, 1, 2)
# (87, 'orange: The Complete Collection 1 (orange: The Complete Collection #1)', 48.41, 1, 1)
# (88, 'Online Marketing for Busy Authors: A Step-By-Step Guide', 46.35, 1, 1)
# (92, 'Masks and Shadows', 56.4, 1, 2)
# (94, 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)', 46.91, 1, 2)
# (95, 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)', 45.61, 1, 3)
# (97, 'Layered: Baking, Building, and Styling Spectacular Cakes', 40.11, 1, 1)
# (98, 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)', 53.9, 1, 2)
# (99, 'Join', 35.67, 1, 5)
# (101, 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine', 57.36, 1, 5)
# (103, 'I am a Hero Omnibus Volume 1', 54.63, 1, 3)
# (104, 'How to Be Miserable: 40 Strategies You Already Use', 46.03, 1, 1)
# (110, 'Everydata: The Misinformation Hidden in the Little Data You Consume Every Day', 54.35, 1, 2)
# (111, "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master", 37.97, 1, 2)
# (112, 'Danganronpa Volume 1', 51.99, 1, 4)
# (113, 'Crown of Midnight (Throne of Glass #2)', 43.29, 1, 3)
# (114, 'Codename Baboushka, Volume 1: The Conclave of Death', 36.72, 1, 4)
# (118, 'Bossypants', 49.46, 1, 2)
# (119, 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))', 37.92, 1, 2)
# (122, 'A World of Flavor: Your Gluten Free Passport', 42.95, 1, 1)
# (123, 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations', 56.76, 1, 5)
# (125, 'A Flight of Arrows (The Pathfinders #2)', 55.53, 1, 5)
# (127, 'A Court of Thorns and Roses (A Court of Thorns and Roses #1)', 52.37, 1, 1)
# (128, '(Un)Qualified: How God Uses Broken People to Do Big Things', 54, 1, 5)
# (130, "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)", 43.3, 1, 4)
# (132, 'Tracing Numbers on a Train', 41.6, 1, 3)
# (134, 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History', 59.64, 1, 1)
# (135, 'Thirteen Reasons Why', 52.72, 1, 1)
# (136, 'The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”', 58.08, 1, 4)
# (138, 'The Vacationers', 42.15, 1, 4)
# (143, 'The Regional Office Is Under Attack!', 51.36, 1, 5)
# (144, 'The Psychopath Test: A Journey Through the Madness Industry', 36, 1, 2)
# (146, 'The Power of Now: A Guide to Spiritual Enlightenment', 43.54, 1, 2)
# (147, "The Omnivore's Dilemma: A Natural History of Four Meals", 38.21, 1, 2)
# (148, 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us', 37.34, 1, 5)
# (149, 'The Murder of Roger Ackroyd (Hercule Poirot #4)', 44.1, 1, 4)
# (150, 'The Mistake (Off-Campus #2)', 43.29, 1, 3)
# (151, "The Matchmaker's Playbook (Wingmen Inc. #1)", 55.85, 1, 1)
# (152, 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking', 37.6, 1, 2)
# (154, 'The Kite Runner', 41.82, 1, 4)
# (155, 'The House by the Lake', 36.95, 1, 1)
# (156, 'The Glittering Court (The Glittering Court #1)', 44.28, 1, 1)
# (157, 'The Girl on the Train', 55.02, 1, 2)
# (160, 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First', 41.25, 1, 1)
# (162, "The Artist's Way: A Spiritual Path to Higher Creativity", 38.49, 1, 5)
# (166, 'Suddenly in Love (Lake Haven #1)', 55.99, 1, 2)
# (173, 'Scarlett Epstein Hates It Here', 43.55, 1, 5)
# (174, 'Romero and Juliet: A Tragic Tale of Love and Zombies', 36.94, 1, 1)
# (176, 'Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form', 41.06, 1, 1)
# (178, 'Nightingale, Sing', 38.28, 1, 1)
# (179, 'Night Sky with Exit Wounds', 41.05, 1, 1)
# (185, 'Library of Souls (Miss Peregrine’s Peculiar Children #3)', 48.56, 1, 5)
# (187, 'I Had a Nice Time And Other Lies...: How to find love & sh*t like that', 57.36, 1, 4)
# (188, 'Hollow City (Miss Peregrine’s Peculiar Children #2)', 42.98, 1, 1)
# (190, 'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond', 49.43, 1, 4)
# (194, 'Finders Keepers (Bill Hodges Trilogy #2)', 53.53, 1, 5)
# (195, 'Fables, Vol. 1: Legends in Exile (Fables #1)', 41.62, 1, 4)
# (196, 'Eureka Trivia 6.0', 54.59, 1, 4)
# (198, 'Done Rubbed Out (Reightman & Bailey #1)', 37.72, 1, 5)
# (199, 'Doing It Over (Most Likely To #1)', 35.61, 1, 3)
# (200, 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals', 42.16, 1, 3)
# (203, 'Close to You', 49.46, 1, 4)
# (204, 'Chasing Heaven: What Dying Taught Me About Living', 37.8, 1, 2)
# (208, 'Batman: The Long Halloween (Batman)', 36.5, 1, 2)
# (211, 'Anonymous', 46.82, 1, 4)
# (213, 'Amid the Chaos', 36.58, 1, 1)
# (214, 'Amatus', 50.54, 1, 5)
# (217, 'You (You #1)', 43.61, 1, 5)
# (218, 'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)', 37.34, 1, 4)
# (220, 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond', 52.65, 1, 4)
# (221, 'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity', 38.2, 1, 4)
# (223, 'We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)', 53.9, 1, 1)
# (225, 'V for Vendetta (V for Vendetta Complete)', 37.1, 1, 4)
# (226, 'Until Friday Night (The Field Party #1)', 46.31, 1, 2)
# (227, 'Unbroken: A World War II Story of Survival, Resilience, and Redemption', 45.95, 1, 2)
# (231, 'The Year of Magical Thinking', 43.04, 1, 2)
# (232, 'The Wright Brothers', 56.8, 1, 4)
# (236, 'The Testament of Mary', 52.67, 1, 4)
# (237, 'The Star-Touched Queen', 46.02, 1, 5)
# (238, 'The Songs of the Gods', 44.48, 1, 5)
# (239, 'The Song of Achilles', 37.4, 1, 5)
# (240, 'The Rosie Project (Don Tillman #1)', 54.04, 1, 1)
# (244, 'The Long Haul (Diary of a Wimpy Kid #9)', 44.07, 1, 1)
# (247, 'The Last Mile (Amos Decker #2)', 54.21, 1, 2)
# (248, 'The Immortal Life of Henrietta Lacks', 40.67, 1, 2)
# (249, 'The Hidden Oracle (The Trials of Apollo #1)', 52.26, 1, 2)
# (253, 'The Dovekeepers', 48.78, 1, 1)
# (254, 'The Darkest Lie', 35.35, 1, 5)
# (255, 'The Bane Chronicles (The Bane Chronicles #1-11)', 44.73, 1, 4)
# (257, 'The 14th Colony (Cotton Malone #11)', 39.24, 1, 1)
# (260, 'Take Me with You', 45.21, 1, 3)
# (261, 'Swell: A Year of Waves', 45.58, 1, 1)
# (264, 'Steve Jobs', 39.5, 1, 5)
# (265, 'Sorting the Beef from the Bull: The Science of Food Fraud Forensics', 44.74, 1, 4)
# (266, 'Someone Like You (The Harrisons #2)', 52.79, 1, 5)
# (267, 'So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)', 35.43, 1, 4)
# (268, 'Shtum', 55.84, 1, 4)
# (269, 'See America: A Celebration of Our National Parks & Treasured Sites', 48.87, 1, 3)
# (270, 'salt.', 46.78, 1, 4)
# (271, 'Robin War', 47.82, 1, 3)
# (274, 'Quarter Life Poetry: Poems for the Young, Broke and Hangry', 50.89, 1, 5)
# (276, 'Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress', 52.15, 1, 3)
# (280, 'Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)', 38.39, 1, 2)
# (281, 'My Name Is Lucy Barton', 41.56, 1, 1)
# (283, 'My Kind of Crazy', 40.36, 1, 1)
# (285, 'More Than Music (Chasing the Dream #1)', 37.61, 1, 2)
# (286, 'Made to Stick: Why Some Ideas Survive and Others Die', 38.85, 1, 5)
# (287, 'Luis Paints the World', 53.95, 1, 3)
# (288, 'Luckiest Girl Alive', 49.83, 1, 3)
# (289, 'Lowriders to the Center of the Earth (Lowriders in Space #2)', 51.51, 1, 2)
# (292, 'Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments', 46.91, 1, 4)
# (300, 'Hush, Hush (Hush, Hush #1)', 47.02, 1, 3)
# (302, 'Hamilton: The Revolution', 58.79, 1, 3)
# (305, 'Glory over Everything: Beyond The Kitchen House', 45.84, 1, 3)
# (306, 'Feathers: Displays of Brilliant Plumage', 49.05, 1, 3)
# (308, 'Every Last Word', 46.47, 1, 3)
# (310, 'El Deafo', 57.62, 1, 5)
# (312, 'Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life', 51.75, 1, 5)
# (313, 'Eat Fat, Get Thin', 54.07, 1, 2)
# (314, "Don't Get Caught", 55.35, 1, 1)
# (315, 'Doctor Sleep (The Shining #2)', 40.12, 1, 2)
# (316, 'Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)', 37.51, 1, 5)
# (318, 'Daily Fantasy Sports', 36.58, 1, 1)
# (319, 'Crazy Love: Overwhelmed by a Relentless God', 47.72, 1, 2)
# (322, 'Clockwork Angel (The Infernal Devices #1)', 44.14, 1, 1)
# (323, 'City of Glass (The Mortal Instruments #3)', 56.02, 1, 4)
# (325, 'City of Bones (The Mortal Instruments #1)', 43.28, 1, 1)
# (326, 'City of Ashes (The Mortal Instruments #2)', 47.27, 1, 1)
# (328, 'Catching Jordan (Hundred Oaks)', 50.83, 1, 3)
# (330, 'Carrie', 46.23, 1, 2)
# (331, 'Buying In: The Secret Dialogue Between What We Buy and Who We Are', 37.8, 1, 4)
# (332, 'Brain on Fire: My Month of Madness', 49.32, 1, 5)
# (335, "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again", 50.62, 1, 5)
# (337, 'Art Ops Vol. 1', 48.8, 1, 3)
# (338, 'Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)', 58.14, 1, 4)
# (340, 'Angels & Demons (Robert Langdon #1)', 51.48, 1, 3)
# (343, 'Abstract City', 56.37, 1, 5)
# (344, 'A Time of Torment (Charlie Parker #14)', 48.35, 1, 5)
# (346, 'A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer', 56.48, 1, 2)
# (347, "A People's History of the United States", 40.79, 1, 2)
# (348, 'A Man Called Ove', 39.72, 1, 1)
# (350, 'A Brush of Wings (Angels Walking #3)', 55.51, 1, 1)
# (353, 'Searching for Meaning in Gailana', 38.73, 1, 1)
# (354, 'Rook', 37.86, 1, 4)
# (358, 'Tipping Point for Planet Earth: How Close Are We to the Edge?', 37.55, 1, 1)
# (360, 'The Silent Sister (Riley MacPherson #1)', 46.29, 1, 5)
# (363, 'The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore', 59.15, 1, 4)
# (364, 'The Golden Condom: And Other Essays on Love Lost and Found', 39.43, 1, 1)
# (366, 'The Dinner Party', 56.54, 1, 2)
# (367, 'The Diary of a Young Girl', 59.9, 1, 3)
# (369, 'Stars Above (The Lunar Chronicles #4.5)', 48.05, 1, 2)
# (371, 'Raspberry Pi Electronics Projects for the Evil Genius', 49.67, 1, 4)
# (372, 'Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two', 43.14, 1, 1)
# (373, 'Psycho: Sanitarium (Psycho #1.5)', 36.97, 1, 5)
# (376, 'No Love Allowed (Dodge Cove #1)', 54.65, 1, 4)
# (377, 'Murder at the 42nd Street Library (Raymond Ambler #1)', 54.36, 1, 4)
# (378, 'Most Wanted', 35.28, 1, 3)
# (380, 'How to Speak Golf: An Illustrated Guide to Links Lingo', 58.32, 1, 5)
# (382, 'Furiously Happy: A Funny Book About Horrible Things', 41.46, 1, 4)
# (384, "Equal Is Unfair: America's Misguided Fight Against Income Inequality", 56.86, 1, 1)
# (385, 'Eleanor & Park', 56.51, 1, 5)
# (386, 'Dirty (Dive Bar #1)', 40.83, 1, 4)
# (387, 'Can You Keep a Secret? (Fear Street Relaunch #4)', 48.64, 1, 1)
# (388, 'Boar Island (Anna Pigeon #19)', 59.48, 1, 3)
# (389, 'A Paris Apartment', 39.01, 1, 4)
# (390, 'A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More', 38.77, 1, 1)
# (391, 'Troublemaker: Surviving Hollywood and Scientology', 48.39, 1, 2)
# (394, 'The Improbability of Love', 59.45, 1, 1)
# (396, 'Take Me Home Tonight (Rock Star Romance #3)', 53.98, 1, 3)
# (397, 'Sleeping Giants (Themis Files #1)', 48.74, 1, 1)
# (400, 'Off the Hook (Fishing for Trouble #1)', 47.67, 1, 3)
# (405, 'Lies and Other Acts of Love', 45.14, 1, 1)
# (406, 'Lab Girl', 40.85, 1, 1)
# (408, "It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle", 56.27, 1, 3)
# (409, 'Grey (Fifty Shades #4)', 48.49, 1, 4)
# (410, 'Exit, Pursued by a Bear', 51.34, 1, 4)
# (418, '11/22/63', 48.48, 1, 3)
# (420, '10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!', 49.71, 1, 5)
# (421, 'Without Shame', 48.27, 1, 5)
# (422, 'Watchmen', 58.05, 1, 4)
# (423, 'Unlimited Intuition Now', 58.87, 1, 4)
# (426, 'The New Brand You: Your New Image Makes the Sale for You', 44.05, 1, 5)
# (429, 'The Fabric of the Cosmos: Space, Time, and the Texture of Reality', 55.91, 1, 1)
# (431, 'The Art and Science of Low Carbohydrate Living', 52.98, 1, 5)
# (432, 'The Alien Club', 54.4, 1, 1)
# (433, 'Suzie Snowflake: One beautiful flake (a self-esteem story)', 54.81, 1, 5)
# (436, 'Modern Day Fables', 47.44, 1, 2)
# (439, 'Dress Your Family in Corduroy and Denim', 43.68, 1, 3)
# (441, "Chernobyl 01:23:40: The Incredible True Story of the World's Worst Nuclear Disaster", 35.92, 1, 2)
# (442, 'Art and Fear: Observations on the Perils (and Rewards) of Artmaking', 48.63, 1, 4)
# (443, 'A Shard of Ice (The Black Symphony Saga #1)', 56.63, 1, 3)
# (444, "A Hero's Curse (The Unseen Chronicles #1)", 50.49, 1, 3)
# (445, '23 Degrees South: A Tropical Tale of Changing Whether...', 35.79, 1, 2)
# (448, 'When Breath Becomes Air', 39.36, 1, 2)
# (449, 'Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel', 36.94, 1, 2)
# (450, 'The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)', 43.62, 1, 5)
# (451, 'The New Drawing on the Right Side of the Brain', 43.02, 1, 3)
# (453, 'The Martian (The Martian #1)', 41.39, 1, 2)
# (454, 'The High Mountains of Portugal', 51.15, 1, 1)
# (455, 'The Grownup', 35.88, 1, 1)
# (456, "The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It", 36.91, 1, 1)
# (458, 'Smarter Faster Better: The Secrets of Being Productive in Life and Business', 38.89, 1, 5)
# (459, 'Silence in the Dark (Logan Point #4)', 58.33, 1, 3)
# (460, 'Shadows of the Past (Logan Point #1)', 39.67, 1, 5)
# (463, 'Proofs of God: Classical Arguments from Tertullian to Barth', 54.21, 1, 1)
# (465, 'Out of Print: City Lights Spotlight No. 14', 53.64, 1, 5)
# (466, 'My Life Next Door (My Life Next Door )', 36.39, 1, 5)
# (467, "Miller's Valley", 58.54, 1, 2)
# (472, 'Left Behind (Left Behind #1)', 40.72, 1, 2)
# (473, "Kill 'Em and Leave: Searching for James Brown and the American Soul", 45.05, 1, 5)
# (474, 'Kierkegaard: A Christian Missionary to Christians', 47.13, 1, 1)
# (476, "I'll Give You the Sun", 56.48, 1, 1)
# (477, 'I Will Find You', 44.21, 1, 1)
# (479, 'Howl and Other Poems', 40.45, 1, 2)
# (481, "Heaven is for Real: A Little Boy's Astounding Story of His Trip to Heaven and Back", 52.86, 1, 2)
# (482, 'Future Shock (Future Shock #1)', 55.65, 1, 5)
# (483, "Ender's Game (The Ender Quintet #1)", 43.64, 1, 1)
# (485, 'Death by Leisure: A Cautionary Tale', 37.51, 1, 4)
# (488, 'Between the World and Me', 56.91, 1, 4)
# (489, 'Being Mortal: Medicine and What Matters in the End', 55.06, 1, 4)
# (491, '32 Yolks', 53.63, 1, 2)
# (492, '"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination', 44.48, 1, 5)
# (496, 'Unreasonable Hope: Finding Faith in the God Who Brings Purpose to Your Pain', 46.33, 1, 2)
# (497, 'Under the Tuscan Sun', 37.33, 1, 3)
# (500, 'The Whale', 35.96, 1, 4)
# (501, 'The Story of Art', 41.14, 1, 4)
# (503, 'The Great Gatsby', 36.05, 1, 4)
# (504, 'The Good Girl', 49.03, 1, 3)
# (506, "The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist", 39.55, 1, 1)
# (507, 'The Drowning Girls', 35.67, 1, 3)
# (509, 'The Bourne Identity (Jason Bourne #1)', 42.78, 1, 4)
# (510, "The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)", 52.3, 1, 5)
# (516, 'Sister Dear', 40.2, 1, 4)
# (517, 'Shrunken Treasures: Literary Classics, Short, Sweet, and Silly', 52.87, 1, 3)
# (518, 'Rich Dad, Poor Dad', 51.74, 1, 1)
# (521, 'Nightstruck: A Novel', 50.35, 1, 4)
# (523, 'Meternity', 43.58, 1, 3)
# (524, 'Memoirs of a Geisha', 49.67, 1, 3)
# (527, 'Leave This Song Behind: Teen Poetry at Its Best', 51.17, 1, 5)
# (528, "King's Folly (The Kinsman Chronicles #1)", 39.61, 1, 5)
# (529, 'John Adams', 57.43, 1, 4)
# (530, 'How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)', 46.01, 1, 4)
# (532, 'Good in Bed (Cannie Shapiro #1)', 37.05, 1, 5)
# (534, 'For the Love: Fighting for Grace in a World of Impossible Standards', 45.13, 1, 3)
# (535, 'Finding God in the Ruins: How God Redeems Pain', 46.64, 1, 2)
# (539, 'Chronicles, Vol. 1', 52.6, 1, 2)
# (541, 'Benjamin Franklin: An American Life', 48.19, 1, 3)
# (543, 'A Summer In Europe', 44.34, 1, 2)
# (544, 'A Short History of Nearly Everything', 52.4, 1, 5)
# (545, 'A Gathering of Shadows (Shades of Magic #2)', 44.81, 1, 4)
# (546, 'The Sound Of Love', 57.84, 1, 5)
# (547, 'The Rise and Fall of the Third Reich: A History of Nazi Germany', 39.67, 1, 2)
# (548, 'The Perks of Being a Wallflower', 55.02, 1, 3)
# (550, 'The Man Who Mistook His Wife for a Hat and Other Clinical Tales', 59.45, 1, 4)
# (552, 'The Joy of Cooking', 43.27, 1, 4)
# (553, 'The Invention of Wings', 37.34, 1, 1)
# (557, 'The God Delusion', 46.85, 1, 3)
# (561, 'The Barefoot Contessa Cookbook', 59.92, 1, 5)
# (562, "Tell the Wolves I'm Home", 50.96, 1, 2)
# (565, 'Musicophilia: Tales of Music and the Brain', 46.58, 1, 1)
# (566, 'Mere Christianity', 48.51, 1, 3)
# (568, 'In the Woods (Dublin Murder Squad #1)', 38.38, 1, 2)
# (569, 'In Cold Blood', 49.98, 1, 4)
# (570, 'How to Stop Worrying and Start Living', 46.49, 1, 5)
# (572, 'Girl, Interrupted', 42.14, 1, 3)
# (573, 'Fun Home: A Family Tragicomic', 56.59, 1, 4)
# (575, 'Deception Point', 40.32, 1, 4)
# (576, 'Death Note, Vol. 6: Give-and-Take (Death Note #6)', 36.39, 1, 3)
# (577, 'Catherine the Great: Portrait of a Woman', 58.55, 1, 4)
# (578, 'Better Homes and Gardens New Cook Book', 39.61, 1, 3)
# (580, 'A Year in Provence (Provence #1)', 56.88, 1, 4)
# (582, 'Will Grayson, Will Grayson (Will Grayson, Will Grayson)', 47.31, 1, 4)
# (583, 'Why Save the Bankers?: And Other Essays on Our Economic and Political Crisis', 48.67, 1, 2)
# (584, 'Where She Went (If I Stay #2)', 41.73, 1, 4)
# (585, 'What If?: Serious Scientific Answers to Absurd Hypothetical Questions', 53.68, 1, 4)
# (587, 'This Is Your Brain on Music: The Science of a Human Obsession', 38.4, 1, 1)
# (590, 'The Raven Boys (The Raven Cycle #1)', 57.74, 1, 4)
# (593, "The Mathews Men: Seven Brothers and the War Against Hitler's U-boats", 42.91, 1, 5)
# (595, 'The Hiding Place', 55.91, 1, 4)
# (597, 'The Firm', 45.56, 1, 3)
# (598, 'The Fault in Our Stars', 47.22, 1, 1)
# (599, 'The False Prince (The Ascendance Trilogy #1)', 56, 1, 5)
# (600, 'The Expatriates', 44.58, 1, 2)
# (603, 'The Crossover', 38.77, 1, 4)
# (605, 'Tell the Wind and Fire', 45.51, 1, 3)
# (606, 'Tell Me Three Things', 41.81, 1, 1)
# (618, 'Last One Home (New Beginnings #1)', 59.98, 1, 3)
# (621, 'Isla and the Happily Ever After (Anna and the French Kiss #3)', 48.13, 1, 5)
# (622, 'If I Stay (If I Stay #1)', 38.13, 1, 5)
# (623, "I Know Why the Caged Bird Sings (Maya Angelou's Autobiography #1)", 36.55, 1, 2)
# (629, 'Evicted: Poverty and Profit in the American City', 42.27, 1, 1)
# (630, 'Drama', 38.7, 1, 2)
# (631, 'Dracula the Un-Dead', 35.63, 1, 5)
# (632, 'Digital Fortress', 58, 1, 5)
# (633, 'Death Note, Vol. 5: Whiteout (Death Note #5)', 52.41, 1, 1)
# (638, 'Approval Junkie: Adventures in Caring Too Much', 58.81, 1, 5)
# (640, "America's War for the Greater Middle East: A Military History", 51.22, 1, 2)
# (641, 'Alight (The Generations Trilogy #2)', 58.59, 1, 4)
# (643, 'A Game of Thrones (A Song of Ice and Fire #1)', 46.42, 1, 2)
# (646, 'Vogue Colors A to Z: A Fashion Coloring Book', 52.35, 1, 4)
# (648, "The Pilgrim's Progress", 50.26, 1, 2)
# (649, 'The Perfect Play (Play by Play #1)', 59.99, 1, 3)
# (651, 'The Jazz of Physics: The Secret Link Between Music and the Structure of the Universe', 38.71, 1, 3)
# (656, 'The Demonists (Demonist #1)', 52.11, 1, 2)
# (658, 'The Bone Hunters (Lexy Vaughan & Steven Macaulay #2)', 59.71, 1, 3)
# (659, 'The Beast (Black Dagger Brotherhood #14)', 46.08, 1, 5)
# (661, 'Shopaholic Ties the Knot (Shopaholic #3)', 48.39, 1, 5)
# (662, 'Paper and Fire (The Great Library #2)', 49.45, 1, 5)
# (667, 'Needful Things', 47.51, 1, 4)
# (675, 'Harry Potter and the Half-Blood Prince (Harry Potter #6)', 48.75, 1, 5)
# (680, 'Fruits Basket, Vol. 4 (Fruits Basket #4)', 50.44, 1, 4)
# (683, 'Confessions of a Shopaholic (Shopaholic #1)', 48.94, 1, 2)
# (685, 'Candide', 58.63, 1, 3)
# (688, 'Animal Farm', 57.22, 1, 3)
# (689, 'A Walk to Remember', 56.43, 1, 1)
# (690, "A New Earth: Awakening to Your Life's Purpose", 55.65, 1, 5)
# (692, "'Salem's Lot", 49.56, 1, 4)
# (696, 'Wild: From Lost to Found on the Pacific Crest Trail', 46.02, 1, 3)
# (703, 'Very Good Lives: The Fringe Benefits of Failure and the Importance of Imagination', 50.66, 1, 3)
# (705, 'Unstuffed: Decluttering Your Home, Mind, and Soul', 58.09, 1, 1)
# (708, 'Twilight (Twilight #1)', 41.93, 1, 2)
# (709, 'Twenties Girl', 42.8, 1, 2)
# (710, "Trespassing Across America: One Man's Epic, Never-Done-Before (and Sort of Illegal) Hike Across the Heartland", 53.51, 1, 1)
# (713, 'The Wild Robot', 56.07, 1, 3)
# (715, 'The Undomestic Goddess', 45.75, 1, 4)
# (718, 'The Thing About Jellyfish', 48.77, 1, 1)
# (719, 'The Stand', 57.86, 1, 2)
# (722, 'The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3)', 55.55, 1, 5)
# (723, 'The Rose & the Dagger (The Wrath and the Dawn #2)', 58.64, 1, 4)
# (725, 'The Rise of Theodore Roosevelt (Theodore Roosevelt #1)', 42.57, 1, 3)
# (728, 'The Red Tent', 35.66, 1, 5)
# (729, 'The Purpose Driven Life: What on Earth Am I Here for?', 37.19, 1, 3)
# (732, 'The Paris Wife', 36.8, 1, 3)
# (733, 'The Obsession', 45.43, 1, 1)
# (735, 'The New Guy (and Other Senior Year Distractions)', 44.92, 1, 3)
# (736, 'The Nanny Diaries (Nanny #1)', 52.53, 1, 5)
# (737, 'The Name of God is Mercy', 37.25, 1, 2)
# (739, "The Lover's Dictionary", 58.09, 1, 2)
# (740, 'The Lonely Ones', 43.59, 1, 5)
# (742, 'The Last Painting of Sara de Vos', 55.55, 1, 2)
# (745, "The Husband's Secret", 52.51, 1, 5)
# (746, "The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy #1)", 47.8, 1, 3)
# (748, 'The Guernsey Literary and Potato Peel Pie Society', 49.53, 1, 1)
# (749, 'The Goldfinch', 43.58, 1, 3)
# (751, 'The Girl with All the Gifts', 49.47, 1, 3)
# (753, "The Girl Who Kicked the Hornet's Nest (Millennium Trilogy #3)", 57.48, 1, 1)
# (754, 'The Exiled', 43.45, 1, 3)
# (757, 'The Disappearing Spoon: And Other True Tales of Madness, Love, and the History of the World from the Periodic Table of the Elements', 57.35, 1, 5)
# (758, 'The Devil Wears Prada (The Devil Wears Prada #1)', 44.29, 1, 1)
# (759, 'The Demon-Haunted World: Science as a Candle in the Dark', 52.25, 1, 4)
# (764, 'The Complete Poems', 41.32, 1, 5)
# (767, 'The Case for Christ (Cases for Christianity)', 47.84, 1, 1)
# (768, 'The Book Thief', 53.49, 1, 2)
# (769, 'The Book of Basketball: The NBA According to The Sports Guy', 44.84, 1, 5)
# (770, 'The Blind Side: Evolution of a Game', 53.71, 1, 5)
# (775, 'Stiff: The Curious Lives of Human Cadavers', 36.74, 1, 3)
# (776, 'Spilled Milk: Based on a True Story', 49.51, 1, 1)
# (777, 'Something Borrowed (Darcy & Rachel #1)', 48.96, 1, 5)
# (778, 'Something Blue (Darcy & Rachel #2)', 54.62, 1, 1)
# (780, 'Shopaholic & Baby (Shopaholic #5)', 46.45, 1, 2)
# (781, 'Seven Days in the Art World', 52.33, 1, 2)
# (784, "Sarah's Key", 46.29, 1, 1)
# (787, 'Rogue Lawyer (Rogue Lawyer #1)', 50.11, 1, 3)
# (788, 'Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars', 41.67, 1, 4)
# (789, 'Rework', 44.88, 1, 2)
# (793, "Quiet: The Power of Introverts in a World That Can't Stop Talking", 43.55, 1, 1)
# (794, 'Prodigy: The Graphic Novel (Legend: The Graphic Novel #2)', 43.63, 1, 3)
# (795, 'Persepolis: The Story of a Childhood (Persepolis #1-2)', 39.13, 1, 1)
# (796, 'Packing for Mars: The Curious Science of Life in the Void', 56.68, 1, 2)
# (801, 'Notes from a Small Island (Notes From a Small Island #1)', 40.17, 1, 1)
# (803, 'Neither Here nor There: Travels in Europe', 38.95, 1, 3)
# (806, 'Miracles from Heaven: A Little Girl, Her Journey to Heaven, and Her Amazing Story of Healing', 57.83, 1, 1)
# (807, 'Midnight Riot (Peter Grant/ Rivers of London - books #1)', 55.46, 1, 2)
# (808, 'Me Talk Pretty One Day', 57.6, 1, 2)
# (813, 'Life Without a Recipe', 59.04, 1, 5)
# (816, "Let's Pretend This Never Happened: A Mostly True Memoir", 45.11, 1, 1)
# (817, 'Legend (Legend #1)', 43.69, 1, 4)
# (819, "Lamb: The Gospel According to Biff, Christ's Childhood Pal", 55.5, 1, 5)
# (820, 'Lady Renegades (Rebel Belle #3)', 53.04, 1, 5)
# (821, 'Jurassic Park (Jurassic Park #1)', 44.97, 1, 1)
# (822, "It's Never Too Late to Begin Again: Discovering Creativity and Meaning at Midlife and Beyond", 42.38, 1, 1)
# (824, 'Into the Wild', 56.7, 1, 5)
# (825, 'Inferno (Robert Langdon #4)', 41, 1, 5)
# (827, 'If I Run (If I Run #1)', 49.97, 1, 4)
# (831, 'House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth', 43.7, 1, 2)
# (832, 'House of Leaves', 54.89, 1, 1)
# (833, 'Horrible Bear!', 37.52, 1, 2)
# (834, 'Holidays on Ice', 51.07, 1, 2)
# (835, 'Heir to the Sky', 44.07, 1, 4)
# (837, 'Grayson, Vol 3: Nemesis (Grayson #3)', 42.72, 1, 1)
# (839, 'Gone Girl', 37.6, 1, 5)
# (840, 'Golden (Heart of Dread #3)', 42.21, 1, 4)
# (841, 'Girl in the Blue Coat', 46.83, 1, 2)
# (842, 'Fruits Basket, Vol. 3 (Fruits Basket #3)', 45.17, 1, 2)
# (843, 'Friday Night Lights: A Town, a Team, and a Dream', 51.22, 1, 3)
# (846, 'Fellside', 38.62, 1, 1)
# (848, 'Eragon (The Inheritance Cycle #1)', 43.87, 1, 3)
# (850, 'Dune (Dune #1)', 54.86, 1, 1)
# (851, 'Dracula', 52.62, 1, 3)
# (852, 'Do Androids Dream of Electric Sheep? (Blade Runner #1)', 51.48, 1, 1)
# (854, 'Dead Wake: The Last Crossing of the Lusitania', 39.24, 1, 5)
# (856, 'Darkfever (Fever #1)', 56.02, 1, 1)
# (858, 'Crazy Rich Asians (Crazy Rich Asians #1)', 49.13, 1, 5)
# (860, 'Cosmos', 36.17, 1, 2)
# (861, 'Civilization and Its Discontents', 59.95, 1, 2)
# (863, "Catastrophic Happiness: Finding Joy in Childhood's Messy Years", 37.35, 1, 2)
# (865, 'Breaking Dawn (Twilight #4)', 35.28, 1, 5)
# (866, 'Brave Enough', 51.32, 1, 5)
# (870, 'Black Flags: The Rise of ISIS', 40.87, 1, 1)
# (871, 'Black Butler, Vol. 1 (Black Butler #1)', 49.31, 1, 1)
# (875, 'Beowulf', 38.35, 1, 2)
# (877, 'Awkward', 38.02, 1, 2)
# (880, 'Are We Smart Enough to Know How Smart Animals Are?', 56.58, 1, 1)
# (881, 'Annie on My Mind', 36.83, 1, 5)
# (886, 'A Heartbreaking Work of Staggering Genius', 54.29, 1, 5)
# (888, '#GIRLBOSS', 50.96, 1, 1)
# (891, "The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)", 54.81, 1, 1)
# (899, 'H is for Hawk', 57.42, 1, 5)
# (900, 'Girl Online On Tour (Girl Online #2)', 53.47, 1, 1)
# (902, 'Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)', 52.88, 1, 4)
# (904, 'While You Were Mine', 41.32, 1, 5)
# (905, 'Where Lightning Strikes (Bleeding Stars #3)', 39.77, 1, 3)
# (906, "When I'm Gone", 51.96, 1, 3)
# (907, 'Ways of Seeing', 39.51, 1, 5)
# (909, 'Vampire Girl (Vampire Girl #1)', 53.82, 1, 2)
# (911, 'Travels with Charley: In Search of America', 57.82, 1, 5)
# (912, 'Three Wishes (River of Time: California #1)', 44.18, 1, 2)
# (913, 'This One Moment (Pushing Limits #1)', 48.71, 1, 1)
# (915, 'The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)', 36.52, 1, 2)
# (916, 'The Tumor', 41.56, 1, 5)
# (917, 'The Story of Hong Gildong', 43.19, 1, 4)
# (919, 'The Silent Twin (Detective Jennifer Knight #3)', 36.25, 1, 3)
# (922, 'The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)', 54.12, 1, 3)
# (925, "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)", 57.7, 1, 4)
# (926, 'The Nicomachean Ethics', 36.34, 1, 1)
# (927, 'The Name of the Wind (The Kingkiller Chronicle #1)', 50.59, 1, 3)
# (929, 'The Little Prince', 45.42, 1, 2)
# (930, 'The Light of the Fireflies', 54.43, 1, 1)
# (931, 'The Last Girl (The Dominion Trilogy #1)', 36.26, 1, 2)
# (933, 'The Hook Up (Game On #1)', 36.29, 1, 5)
# (941, 'The Bhagavad Gita', 57.49, 1, 3)
# (943, 'The Art of Not Breathing', 40.83, 1, 4)
# (946, 'Skip Beat!, Vol. 01 (Skip Beat! #1)', 42.12, 1, 3)
# (948, 'Shatter Me (Shatter Me #1)', 42.4, 1, 1)
# (949, 'Shameless', 58.35, 1, 3)
# (951, 'Settling the Score (The Summer Games #1)', 44.91, 1, 2)
# (952, 'Sense and Sensibility', 37.46, 1, 1)
# (955, 'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)', 46.96, 1, 5)
# (960, 'One Second (Seven #7)', 52.94, 1, 2)
# (962, "Old Records Never Die: One Man's Quest for His Vinyl and His Past", 55.66, 1, 2)
# (963, 'Off Sides (Off #1)', 39.45, 1, 5)
# (964, 'Of Mice and Men', 47.11, 1, 2)
# (965, 'Myriad (Prentor #1)', 58.75, 1, 4)
# (966, 'My Perfect Mistake (Over the Top #1)', 38.92, 1, 2)
# (967, 'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)', 39.39, 1, 4)
# (972, 'Listen to Me (Fusion #1)', 58.99, 1, 3)
# (973, 'Kitchens of the Great Midwest', 57.2, 1, 5)
# (974, 'Jane Eyre', 38.43, 1, 5)
# (976, 'Icing (Aces Hockey #2)', 40.44, 1, 4)
# (977, 'Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)', 45.24, 1, 3)
# (979, 'Giant Days, Vol. 1 (Giant Days #1-4)', 56.76, 1, 4)
# (980, 'Fruits Basket, Vol. 1 (Fruits Basket #1)', 40.28, 1, 5)
# (981, 'Frankenstein', 38, 1, 2)
# (983, 'Fighting Fate (Fighting #6)', 39.24, 1, 3)
# (985, 'Eat, Pray, Love', 51.32, 1, 3)
# (986, 'Deep Under (Walker Security #1)', 47.09, 1, 5)
# (989, "Charity's Cross (Charles Towne Belles #4)", 41.24, 1, 1)
# (990, 'Bright Lines', 39.07, 1, 5)
# (992, 'Bounty (Colorado Mountain #7)', 37.26, 1, 4)
# (995, 'Beyond Good and Evil', 43.38, 1, 1)
# (996, "Alice in Wonderland (Alice's Adventures in Wonderland #1)", 55.53, 1, 1)
# (997, 'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)', 57.06, 1, 4)
# (999, "1st to Die (Women's Murder Club #1)", 53.98, 1, 1)

# %%
# Trouver les livres dont le titre contient "light"
# Out:
# Livres contenant 'light' dans le titre : 14
# (1, 'A Light in the Attic', 51.77, 1, 3)
# (125, 'A Flight of Arrows (The Pathfinders #2)', 55.53, 1, 5)
# (146, 'The Power of Now: A Guide to Spiritual Enlightenment', 43.54, 1, 2)
# (341, 'All the Light We Cannot See', 29.87, 1, 5)
# (465, 'Out of Print: City Lights Spotlight No. 14', 53.64, 1, 5)
# (486, 'Brilliant Beacons: A History of the American Lighthouse', 11.45, 1, 3)
# (641, 'Alight (The Generations Trilogy #2)', 58.59, 1, 4)
# (708, 'Twilight (Twilight #1)', 41.93, 1, 2)
# (843, 'Friday Night Lights: A Town, a Team, and a Dream', 51.22, 1, 3)
# (849, 'Eclipse (Twilight #3)', 18.74, 1, 1)
# (865, 'Breaking Dawn (Twilight #4)', 35.28, 1, 5)
# (896, 'New Moon (Twilight #2)', 12.86, 1, 4)
# (905, 'Where Lightning Strikes (Bleeding Stars #3)', 39.77, 1, 3)
# (930, 'The Light of the Fireflies', 54.43, 1, 1)

# %% [markdown]
# On récupère des titres avec le mot "light" mais également des titres contenant un mot qui contient "light" comme sous-mot ("Twilight" ou autre).
#
# **BONUS**
#
# Trouver les titres contenant exactement le mot "light".
